# %%
pip install jupyter-dash
# Out:
# Requirement already satisfied: jupyter-dash in c:\users\jenni\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: ansi2html in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: ipython in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (7.19.0)
# Requirement already satisfied: retrying in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: flask in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: requests in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (2.24.0)
# Requirement already satisfied: dash in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (1.20.0)
# Requirement already satisfied: ipykernel in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-dash) (5.3.4)
# Requirement already satisfied: decorator in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (50.3.1.post20201107)
# Requirement already satisfied: pickleshare in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.4)
# Requirement already satisfied: backcall in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: jedi>=0.10 in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.17.1)
# Requirement already satisfied: traitlets>=4.2 in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.0.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.8)
# Requirement already satisfied: pygments in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.7.2)
# Requirement already satisfied: six>=1.7.0 in c:\users\jenni\anaconda3\lib\site-packages (from retrying->jupyter-dash) (1.15.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\jenni\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\jenni\anaconda3\lib\site-packages (from flask->jupyter-dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\jenni\anaconda3\lib\site-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\jenni\anaconda3\lib\site-packages (from flask->jupyter-dash) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jenni\anaconda3\lib\site-packages (from requests->jupyter-dash) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\jenni\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jenni\anaconda3\lib\site-packages (from requests->jupyter-dash) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\jenni\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.0.4)
# Requirement already satisfied: dash-core-components==1.16.0 in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.16.0)
# Requirement already satisfied: dash-html-components==1.1.3 in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.1.3)
# Requirement already satisfied: dash-table==4.11.3 in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.11.3)
# Requirement already satisfied: plotly in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.14.3)
# Requirement already satisfied: dash-renderer==1.9.1 in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.9.1)
# Requirement already satisfied: future in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (0.18.2)
# Requirement already satisfied: flask-compress in c:\users\jenni\anaconda3\lib\site-packages (from dash->jupyter-dash) (1.9.0)
# Requirement already satisfied: tornado>=4.2 in c:\users\jenni\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.0.4)
# Requirement already satisfied: jupyter-client in c:\users\jenni\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.1.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\jenni\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: ipython-genutils in c:\users\jenni\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\jenni\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jenni\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\jenni\anaconda3\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (4.6.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (19.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash) (227)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jenni\anaconda3\lib\site-packages (1.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jenni\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\jenni\anaconda3\lib\site-packages (from pandas) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\jenni\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\jenni\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
pip install jupyter_plotly_dash
# Out:
# Collecting jupyter_plotly_dash
#   Using cached jupyter_plotly_dash-0.4.3-py3-none-any.whl (29 kB)
# Collecting nbserverproxy
#   Using cached nbserverproxy-0.8.8-py3-none-any.whl (7.5 kB)
# Collecting django-bootstrap4
#   Using cached django_bootstrap4-3.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jupyter in c:\users\jenni\anaconda3\lib\site-packages (from jupyter_plotly_dash) (1.0.0)
# Collecting dpd-components
#   Using cached dpd_components-0.1.0.tar.gz (4.3 kB)
# Collecting dpd-static-support
#   Using cached dpd_static_support-0.0.5-py3-none-any.whl (509 kB)
# Collecting aiohttp
#   Using cached aiohttp-3.7.4.post0-cp38-cp38-win_amd64.whl (635 kB)
# Collecting django-plotly-dash
#   Using cached django_plotly_dash-1.6.3-py3-none-any.whl (50 kB)
# Requirement already satisfied: notebook in c:\users\jenni\anaconda3\lib\site-packages (from nbserverproxy->jupyter_plotly_dash) (6.1.4)
# Collecting Django>=2.2
#   Using cached Django-3.2-py3-none-any.whl (7.9 MB)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in c:\users\jenni\anaconda3\lib\site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.9.3)
# Requirement already satisfied: nbconvert in c:\users\jenni\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.0.7)
# Requirement already satisfied: jupyter-console in c:\users\jenni\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.2.0)
# Requirement already satisfied: qtconsole in c:\users\jenni\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (4.7.7)
# Requirement already satisfied: ipykernel in c:\users\jenni\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.3.4)
# Requirement already satisfied: ipywidgets in c:\users\jenni\anaconda3\lib\site-packages (from jupyter->jupyter_plotly_dash) (7.5.1)
# Collecting async-timeout<4.0,>=3.0
#   Using cached async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.6.3-cp38-cp38-win_amd64.whl (125 kB)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\jenni\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (3.7.4.3)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-5.1.0-cp38-cp38-win_amd64.whl (48 kB)
# Requirement already satisfied: chardet<5.0,>=2.0 in c:\users\jenni\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jenni\anaconda3\lib\site-packages (from aiohttp->jupyter_plotly_dash) (20.3.0)
# Requirement already satisfied: dash-core-components in c:\users\jenni\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.16.0)
# Requirement already satisfied: dash>=1.11 in c:\users\jenni\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.20.0)
# Requirement already satisfied: dash-renderer in c:\users\jenni\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.9.1)
# Requirement already satisfied: dash-html-components in c:\users\jenni\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.3)
# Requirement already satisfied: Flask>=1.0.2 in c:\users\jenni\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.2)
# Requirement already satisfied: plotly in c:\users\jenni\anaconda3\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (4.14.3)
# Requirement already satisfied: tornado>=5.0 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (6.0.4)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.9.1)
# Requirement already satisfied: prometheus-client in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (20.1.0)
# Requirement already satisfied: Send2Trash in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: nbformat in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (5.0.8)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (4.6.3)
# Requirement already satisfied: jinja2 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (2.11.2)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (6.1.7)
# Requirement already satisfied: ipython-genutils in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (5.0.5)
# Requirement already satisfied: pyzmq>=17 in c:\users\jenni\anaconda3\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (19.0.2)
# Requirement already satisfied: pytz in c:\users\jenni\anaconda3\lib\site-packages (from Django>=2.2->django-bootstrap4->jupyter_plotly_dash) (2020.1)
# Collecting asgiref<4,>=3.3.2
#   Using cached asgiref-3.3.4-py3-none-any.whl (22 kB)
# Collecting sqlparse>=0.2.2
#   Using cached sqlparse-0.4.1-py3-none-any.whl (42 kB)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\jenni\anaconda3\lib\site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (2.0.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (2.7.2)
# Requirement already satisfied: testpath in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: bleach in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (3.2.1)
# Requirement already satisfied: defusedxml in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jenni\anaconda3\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.4.3)
# Requirement already satisfied: ipython in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (7.19.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (3.0.8)
# Requirement already satisfied: qtpy in c:\users\jenni\anaconda3\lib\site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (1.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jenni\anaconda3\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.5.1)
# Requirement already satisfied: idna>=2.0 in c:\users\jenni\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (2.10)
# Requirement already satisfied: future in c:\users\jenni\anaconda3\lib\site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (0.18.2)
# Requirement already satisfied: flask-compress in c:\users\jenni\anaconda3\lib\site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.3 in c:\users\jenni\anaconda3\lib\site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (4.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\jenni\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\jenni\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\jenni\anaconda3\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (7.1.2)
# Requirement already satisfied: six in c:\users\jenni\anaconda3\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\jenni\anaconda3\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.3.3)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\jenni\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->nbserverproxy->jupyter_plotly_dash) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\jenni\anaconda3\lib\site-packages (from argon2-cffi->notebook->nbserverproxy->jupyter_plotly_dash) (1.14.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\jenni\anaconda3\lib\site-packages (from nbformat->notebook->nbserverproxy->jupyter_plotly_dash) (3.2.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook->nbserverproxy->jupyter_plotly_dash) (227)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jenni\anaconda3\lib\site-packages (from jinja2->notebook->nbserverproxy->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\jenni\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook->nbserverproxy->jupyter_plotly_dash) (2.8.1)
# Requirement already satisfied: webencodings in c:\users\jenni\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: packaging in c:\users\jenni\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (20.4)
# Requirement already satisfied: nest-asyncio in c:\users\jenni\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter_plotly_dash) (1.4.2)
# Requirement already satisfied: async-generator in c:\users\jenni\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter_plotly_dash) (1.10)
# Requirement already satisfied: decorator in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (4.4.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (50.3.1.post20201107)
# Requirement already satisfied: jedi>=0.10 in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.17.1)
# Requirement already satisfied: backcall in c:\users\jenni\anaconda3\lib\site-packages (from ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\jenni\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyter_plotly_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\jenni\anaconda3\lib\site-packages (from flask-compress->dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (1.0.9)
# Requirement already satisfied: pycparser in c:\users\jenni\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->nbserverproxy->jupyter_plotly_dash) (2.20)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\jenni\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->nbserverproxy->jupyter_plotly_dash) (0.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\jenni\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->jupyter->jupyter_plotly_dash) (2.4.7)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\jenni\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter-console->jupyter->jupyter_plotly_dash) (0.7.0)
# Building wheels for collected packages: dpd-components
#   Building wheel for dpd-components (setup.py): started
#   Building wheel for dpd-components (setup.py): finished with status 'done'
#   Created wheel for dpd-components: filename=dpd_components-0.1.0-py3-none-any.whl size=4571 sha256=ab3853b6e669c553a6efabbd73471bb83c2ab61af8f872daed7030322858d8d9
#   Stored in directory: c:\users\jenni\appdata\local\pip\cache\wheels\07\a3\74\51b984d053f5e36de2d3bdfeb5dbadec7896d0af2dd7f4446e
# Note: you may need to restart the kernel to use updated packages.
# Successfully built dpd-components
# Installing collected packages: nbserverproxy, asgiref, sqlparse, Django, django-bootstrap4, dpd-components, dpd-static-support, async-timeout, multidict, yarl, aiohttp, django-plotly-dash, jupyter-plotly-dash
# Successfully installed Django-3.2 aiohttp-3.7.4.post0 asgiref-3.3.4 async-timeout-3.0.1 django-bootstrap4-3.0.0 django-plotly-dash-1.6.3 dpd-components-0.1.0 dpd-static-support-0.0.5 jupyter-plotly-dash-0.4.3 multidict-5.1.0 nbserverproxy-0.8.8 sqlparse-0.4.1 yarl-1.6.3

# %%
import pandas as pd
import plotly.express as px

import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

app = dash.Dash(__name__)

df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")


app.layout = html.Div([
    
        
    html.H1("Wieso?", style = {'text-align': 'center'}),
    html.H4("Numbers and facts about Covid-19", style = {'text-align': 'left'}),

    dcc.Dropdown(id='continent',
                 options = [
                     {"label": "Africa", "value": 'Africa'},
                     {"label": "Asia", "value": 'Asia'},
                     {"label": "Europe", "value": 'Europe'},
                     {"label": "North America", "value": 'North America'},
                     {"label": "Oceania", "value": 'Oceania'},
                     {"label": "South America", "value": 'South America'}],
                 multi = False,
                 value='Europe',
                 style = {"width": "40%"}),
    
        
    dcc.Graph(id='covidplot', figure = {}),
    html.Br(),
    
    dcc.Graph(id='covidplot2', figure = {})
])

@app.callback(
    [Output(component_id='covidplot', component_property='figure'),
     Output(component_id='covidplot2', component_property='figure')],
    [Input(component_id='continent', component_property='value')]
)

def update_graph(option_slctd):
    dff = df.copy()
    dff = dff[dff["continent"] == option_slctd]
    
    
# Plotly Express
    fig = px.line(dff, x='date', y='new_cases')

    fig2 = px.scatter(dff, x="new_cases", y="new_deaths", 
                     color = "location", size = "gdp_per_capita",
                     marginal_x = "box", marginal_y = "box", trendline = "ols")


    return fig, fig2


if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
